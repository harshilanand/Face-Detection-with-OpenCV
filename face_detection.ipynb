# %% [markdown]
# <a href="https://colab.research.google.com/github/harshilanand/Face-Detection-with-OpenCV/blob/main/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
# %matplotlib inline

# %%
image1 = cv2.imread("/content/IMG_20201017_090935.jpg", cv2.IMREAD_UNCHANGED)
image2 = cv2.imread("/content/IMG_20201218_171352.jpg", cv2.IMREAD_UNCHANGED)
image3 = cv2.imread("/content/birthday.jpg", cv2.IMREAD_UNCHANGED)

# %%
# cv2_imshow(image3)

# %%
imgage11 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
imgage22 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
imgage33 = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)

# %%
# cv2_imshow(img_gray)

# %%
cv2.data.haarcascades
# Out:
# '/usr/local/lib/python3.10/dist-packages/cv2/data/'

# %%
face_detector = cv2.CascadeClassifier(cv2.data.haarcascades +
'haarcascade_frontalface_default.xml' )

# %%
def detect_face (image):
    face_image = image.copy()
    face_rectangle = face_detector.detectMultiScale(face_image)
    for (x,y,width,height) in face_rectangle:
      cv2.rectangle(face_image, (x,y), (x + width, y+height), (255,255,255), 8)
      return face_image

# %%
detection_result = detect_face(imgage11)

# %%
# cv2_imshow(detection_result)

# %%
# detection_result = detect_face(image3)
# cv2_imshow(detection_result)

# %%
face_detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml')

# %%
def detect_face (image):
  face_image = image.copy()
  face_rectangle = face_detector.detectMultiScale(face_image)
  for (x,y,width,height) in face_rectangle:
    cv2.rectangle(face_image, (x,y), (x + width, y+height), (255,255,255), 8)
    return face_image

# %%
# detection_result = detect_face(image3)
# cv2_imshow(detection_result)

# %%
# detection_result = detect_face(image2)
# cv2_imshow(detection_result)

# %%
face_detector = cv2.CascadeClassifier(cv2.data.haarcascades +
'haarcascade_frontalface_alt_tree.xml' )

# %%
def detect_face (image):
  face_image = image.copy()
  face_rectangle = face_detector.detectMultiScale(face_image)
  for (x,y,width,height) in face_rectangle:
    cv2.rectangle(face_image, (x,y), (x + width, y+height), (255,255,255), 8)
    return face_image

# %%
# detection_result = detect_face(image2)
# cv2_imshow(detection_result)

# %%
# detection_result = detect_face(image3)
# cv2_imshow(detection_result)

# %%
face_detector = cv2.CascadeClassifier(cv2.data.haarcascades +
'haarcascade_frontalface_alt.xml' )

# %%
def detect_face (image):
  face_image = image.copy()
  face_rectangle = face_detector.detectMultiScale(face_image)
  for (x,y,width,height) in face_rectangle:
    cv2.rectangle(face_image, (x,y), (x + width, y+height), (255,255,255), 8)
    return face_image

# %%
detection_result = detect_face(imgage33)
cv2_imshow(detection_result)
# Out:
# <PIL.Image.Image image mode=L size=1280x960>

# %%
eye_detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml' )

# %%
def detect_eye (image):
  face_image = image.copy()
  face_rectangle = eye_detector.detectMultiScale(face_image)
  for (x,y,width,height) in face_rectangle:
    cv2.rectangle(face_image, (x,y), (x + width, y+height), (255,255,255), 8)
    return face_image

# %%
detection_result = detect_eye(imgage22)
cv2_imshow(detection_result)
# Out:
# <PIL.Image.Image image mode=L size=1280x853>

# %%
detection_result = detect_eye(imgage33)
cv2_imshow(detection_result)
# Out:
# <PIL.Image.Image image mode=L size=1280x960>
